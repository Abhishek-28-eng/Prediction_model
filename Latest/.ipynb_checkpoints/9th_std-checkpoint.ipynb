# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

# %%
data_9th=pd.read_csv("9th_std.csv")
data_9th
# Out:
#        Marathi  Urdu  Hindi  English  History  Science  Geography  Drawing  \
# 0           45    24     71       20       54       65         71       52
# 1           88    31    100       97       93       53         11       11
# 2           85    54     75       77        9       70         74       57
# 3           86    77     59       40       47       65         46       98
# 4          100     4     68       13       85       16         68       18
# ...        ...   ...    ...      ...      ...      ...        ...      ...
# 99995       24    12      1       99       41       39          4       29
# 99996       30    23     53       88       26       14         46       14
# 99997       85    84     34       98       45       15         12       19
# 99998      100    66     53       96       98       25         51       14
# 99999        3    46     61       74       85       64         53       44
#
#        Sports  Environmental Studies  Algebra  Geometry  Computer  Defence  \
# 0          49                     89       52        93        81       28
# 1          23                    100       33        38        57       30
# 2          16                    100      100        23        85       31
# 3          98                     86        7        51        47       87
# 4          16                     50        4        96        45       60
# ...       ...                    ...      ...       ...       ...      ...
# 99995      72                     43       92        94        91       80
# 99996      36                     46       82        48         9       19
# 99997      83                     35       29        70        79       96
# 99998      22                     63       27        52        50       47
# 99999      85                     69       81        67        50       44
#
#                     Interest
# 0                   Geometry
# 1      Environmental Studies
# 2                    Algebra
# 3                     Sports
# 4                    Marathi
# ...                      ...
# 99995                English
# 99996                English
# 99997                English
# 99998                Marathi
# 99999                History
#
# [100000 rows x 15 columns]

# %%
data_9th.dtypes
# Out:
# Marathi                   int64
# Urdu                      int64
# Hindi                     int64
# English                   int64
# History                   int64
# Science                   int64
# Geography                 int64
# Drawing                   int64
# Sports                    int64
# Environmental Studies     int64
# Algebra                   int64
# Geometry                  int64
# Computer                  int64
# Defence                   int64
# Interest                 object
# dtype: object

# %%
new_9th = data_9th.drop(['Interest'], axis=1)
new_9th
# Out:
#        Marathi  Urdu  Hindi  English  History  Science  Geography  Drawing  \
# 0           45    24     71       20       54       65         71       52
# 1           88    31    100       97       93       53         11       11
# 2           85    54     75       77        9       70         74       57
# 3           86    77     59       40       47       65         46       98
# 4          100     4     68       13       85       16         68       18
# ...        ...   ...    ...      ...      ...      ...        ...      ...
# 99995       24    12      1       99       41       39          4       29
# 99996       30    23     53       88       26       14         46       14
# 99997       85    84     34       98       45       15         12       19
# 99998      100    66     53       96       98       25         51       14
# 99999        3    46     61       74       85       64         53       44
#
#        Sports  Environmental Studies  Algebra  Geometry  Computer  Defence
# 0          49                     89       52        93        81       28
# 1          23                    100       33        38        57       30
# 2          16                    100      100        23        85       31
# 3          98                     86        7        51        47       87
# 4          16                     50        4        96        45       60
# ...       ...                    ...      ...       ...       ...      ...
# 99995      72                     43       92        94        91       80
# 99996      36                     46       82        48         9       19
# 99997      83                     35       29        70        79       96
# 99998      22                     63       27        52        50       47
# 99999      85                     69       81        67        50       44
#
# [100000 rows x 14 columns]

# %%
new_9th.insert(0, 'Unique_ID', [f"stud_{i}" for i in range(1, len(new_7th) + 1)])
new_9th

# %%
# Ensure all subject columns are numeric
new_9th.iloc[:, 1:] = new_9th.iloc[:, 1:].apply(pd.to_numeric, errors="coerce")

# Function to find top and second-top subjects excluding Unique_ID
def find_top_interests(row):
    # Exclude the Unique_ID column
    subject_marks = {subject: mark for subject, mark in row.items() if subject != "Unique_ID"}
    
    # Find the highest and second-highest marks
    unique_marks = sorted(set(subject_marks.values()), reverse=True)
    if len(unique_marks) >= 2:
        top_marks = unique_marks[:2]  # Top two unique marks
    elif len(unique_marks) == 1:
        top_marks = unique_marks  # Only one unique mark
    else:
        top_marks = []  # No marks present
    
    # Collect all subjects with marks in top_marks
    top_subjects = [subject for subject, mark in subject_marks.items() if mark in top_marks]
    return ", ".join(top_subjects)

# Apply the function to find the Interest column
new_9th["Interest"] = new_9th.apply(find_top_interests, axis=1)
new_9th
file_path = "Latest9th.csv"  # Specify your desired file path
new_9th.to_csv(file_path, index=False)  # Save the DataFrame without the index
print(f"CSV file saved")
# Out:
#        Marathi  Urdu  Hindi  English  History  Science  Geography  Drawing  \
# 0           45    24     71       20       54       65         71       52
# 1           88    31    100       97       93       53         11       11
# 2           85    54     75       77        9       70         74       57
# 3           86    77     59       40       47       65         46       98
# 4          100     4     68       13       85       16         68       18
# ...        ...   ...    ...      ...      ...      ...        ...      ...
# 99995       24    12      1       99       41       39          4       29
# 99996       30    23     53       88       26       14         46       14
# 99997       85    84     34       98       45       15         12       19
# 99998      100    66     53       96       98       25         51       14
# 99999        3    46     61       74       85       64         53       44
#
#        Sports  Environmental Studies  Algebra  Geometry  Computer  Defence  \
# 0          49                     89       52        93        81       28
# 1          23                    100       33        38        57       30
# 2          16                    100      100        23        85       31
# 3          98                     86        7        51        47       87
# 4          16                     50        4        96        45       60
# ...       ...                    ...      ...       ...       ...      ...
# 99995      72                     43       92        94        91       80
# 99996      36                     46       82        48         9       19
# 99997      83                     35       29        70        79       96
# 99998      22                     63       27        52        50       47
# 99999      85                     69       81        67        50       44
#
#                                                 Interest
# 0                        Environmental Studies, Geometry
# 1                  Hindi, English, Environmental Studies
# 2      Marathi, Environmental Studies, Algebra, Computer
# 3                               Drawing, Sports, Defence
# 4                                      Marathi, Geometry
# ...                                                  ...
# 99995                                  English, Geometry
# 99996                                   English, Algebra
# 99997                                   English, Defence
# 99998                                   Marathi, History
# 99999                           History, Sports, Algebra
#
# [100000 rows x 15 columns]
