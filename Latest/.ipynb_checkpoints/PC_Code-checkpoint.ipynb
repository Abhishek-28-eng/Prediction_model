# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from collections import Counter

# %%
df_5th=pd.read_csv("Latest5th.csv")
df_5th
# Out:
#         Unique_ID  Marathi  Urdu  Hindi  English  History  Science  Geography  \
# 0          stud_1       25    33     33       83       63       13         20
# 1          stud_2       52    58     64       24       34       20         43
# 2          stud_3       76    24     94       29       91       10         28
# 3          stud_4       41    70     81       98       74       13         40
# 4          stud_5       88    54     49       78        2       11         90
# ...           ...      ...   ...    ...      ...      ...      ...        ...
# 9996    stud_9997       62    11     74       71       83       60         83
# 9997    stud_9998       34    72     78       56       80      100         90
# 9998    stud_9999       68    26     39       80       59        2         68
# 9999   stud_10000       87    49     16       60       33       29         57
# 10000  stud_10001      100    98     27       96      100       71         36
#
#        Drawing  Sports  Environmental Studies  Math  Computer  \
# 0           92      99                     45    99        71
# 1           89      89                     20    56        31
# 2           86      52                     14    12        62
# 3           56      25                     36    35        64
# 4           80      89                     37    64        91
# ...        ...     ...                    ...   ...       ...
# 9996        78      97                     67     4        22
# 9997        67      55                     38    90        32
# 9998        91      45                      3    52        72
# 9999        53      91                     91    62        82
# 10000       68      79                     41    83        47
#
#                                      Interest
# 0                       Drawing, Sports, Math
# 1                      Hindi, Drawing, Sports
# 2                              Hindi, History
# 3                              Hindi, English
# 4                         Geography, Computer
# ...                                       ...
# 9996               History, Geography, Sports
# 9997                 Science, Geography, Math
# 9998                         English, Drawing
# 9999   Marathi, Sports, Environmental Studies
# 10000                  Marathi, Urdu, History
#
# [10001 rows x 14 columns]

# %%
df_6th=pd.read_csv("Latest6th.csv")
df_6th
# Out:
#        Unique_ID  Marathi  Urdu  Hindi  English  History  Science  Geography  \
# 0         stud_1       39    46     54       35       71       64         74
# 1         stud_2       54    56     69       54       72       27         22
# 2         stud_3       59    68     22       77       60       36         74
# 3         stud_4       31    61     40       25       26       61         78
# 4         stud_5       52    25     22       21       59       35         44
# ...          ...      ...   ...    ...      ...      ...      ...        ...
# 9995   stud_9996       71    79     27       23       40       54         20
# 9996   stud_9997       57    56     77       72       23       22         43
# 9997   stud_9998       22    75     69       33       25       74         35
# 9998   stud_9999       26    20     72       58       25       58         46
# 9999  stud_10000       58    41     53       24       32       63         60
#
#       Drawing  Sports  Environmental Studies  Math  Computer  \
# 0          53      28                     20    74        67
# 1          79      47                     79    65        25
# 2          71      55                     79    76        53
# 3          22      38                     76    24        60
# 4          53      62                     45    24        76
# ...       ...     ...                    ...   ...       ...
# 9995       49      56                     59    31        73
# 9996       43      25                     23    41        21
# 9997       44      80                     30    53        49
# 9998       46      80                     35    75        51
# 9999       21      69                     80    60        56
#
#                                      Interest
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
# [10000 rows x 14 columns]

# %%
df_7th=pd.read_csv("Latest7th.csv")
df_7th
# Out:
#        Unique_ID  Marathi  Urdu  Hindi  English  History  Science  Geography  \
# 0         stud_1       74    46     74       35       74       64         74
# 1         stud_2       54    90     69       54       72       90         22
# 2         stud_3       59    68     22       82       60       82         74
# 3         stud_4       31    61     40       25       26       93         93
# 4         stud_5       52    25     22       21       59       35         44
# ...          ...      ...   ...    ...      ...      ...      ...        ...
# 9995   stud_9996       71    79     27       23       40       54         20
# 9996   stud_9997       57    56     77       72       23       22         43
# 9997   stud_9998       22    75     69       33       25       74         35
# 9998   stud_9999       26    20     72       58       25       58         46
# 9999  stud_10000       58    41     53       24       32       63         60
#
#       Drawing  Sports  Environmental Studies  Math  Computer  \
# 0          53      28                     20    74        67
# 1          79      90                     79    65        25
# 2          71      55                     79    82        82
# 3          93      38                     93    24        60
# 4          53      62                     45    24        76
# ...       ...     ...                    ...   ...       ...
# 9995       49      56                     59    31        73
# 9996       43      25                     23    41        21
# 9997       44      80                     30    53        49
# 9998       46      80                     35    75        51
# 9999       21      69                     80    60        56
#
#                                                Interest
# 0     Marathi, Hindi, History, Geography, Math, Comp...
# 1     Urdu, Science, Drawing, Sports, Environmental ...
# 2     English, Science, Environmental Studies, Math,...
# 3     Urdu, Science, Geography, Drawing, Environment...
# 4                                      Sports, Computer
# ...                                                 ...
# 9995                                     Urdu, Computer
# 9996                                     Hindi, English
# 9997                                       Urdu, Sports
# 9998                                       Sports, Math
# 9999                      Sports, Environmental Studies
#
# [10000 rows x 14 columns]

# %%
df_8th=pd.read_csv("Latest8th.csv")
df_8th
# Out:
#         Unique_ID  Marathi  Urdu  Hindi  English  History  Science  Geography  \
# 0          stud_1       87    14     24       84       87       15         15
# 1          stud_2        3    98     70       36       98       54         33
# 2          stud_3       64   100     23       90       63      100         34
# 3          stud_4       66    70     24       91       10       18         70
# 4          stud_5       79    79     74       13       38       31         61
# ...           ...      ...   ...    ...      ...      ...      ...        ...
# 9996    stud_9997       66    78     42       69       59        3          9
# 9997    stud_9998       71    69     51       11       83       96         69
# 9998    stud_9999       49    92      1       90       55       87         74
# 9999   stud_10000       25    63     42       25       51       21         12
# 10000  stud_10001       41    21     89       90       78        2         34
#
#        Drawing  Sports  Environmental Studies  Math  Computer  \
# 0           64      69                      1    61        60
# 1           14      77                     76    86        14
# 2           21      16                     21    38        88
# 3          100      19                    100    65        71
# 4           83      57                     21    34         4
# ...        ...     ...                    ...   ...       ...
# 9996        20      93                     72    11        44
# 9997        41       8                     98    40         7
# 9998        92      44                     27     9        82
# 9999        57      37                     40    70        81
# 10000       52      46                      4    81        57
#
#                                       Interest
# 0                    Marathi, English, History
# 1                          Urdu, History, Math
# 2                       Urdu, English, Science
# 3      English, Drawing, Environmental Studies
# 4                       Marathi, Urdu, Drawing
# ...                                        ...
# 9996                              Urdu, Sports
# 9997            Science, Environmental Studies
# 9998                    Urdu, English, Drawing
# 9999                            Math, Computer
# 10000                           Hindi, English
#
# [10001 rows x 14 columns]

# %%
df_9th=pd.read_csv("Latest9th.csv")
df_9th
# Out:
#          Unique_ID  Marathi  Urdu  Hindi  English  History  Science  \
# 0           stud_1       45    24     71       20       54       65
# 1           stud_2       88    31    100       97       93       53
# 2           stud_3       85    54     75       77        9       70
# 3           stud_4       86    77     59       40       47       65
# 4           stud_5      100     4     68       13       85       16
# ...            ...      ...   ...    ...      ...      ...      ...
# 99995   stud_99996       24    12      1       99       41       39
# 99996   stud_99997       30    23     53       88       26       14
# 99997   stud_99998       85    84     34       98       45       15
# 99998   stud_99999      100    66     53       96       98       25
# 99999  stud_100000        3    46     61       74       85       64
#
#        Geography  Drawing  Sports  Environmental Studies  Algebra  Geometry  \
# 0             71       52      49                     89       52        93
# 1             11       11      23                    100       33        38
# 2             74       57      16                    100      100        23
# 3             46       98      98                     86        7        51
# 4             68       18      16                     50        4        96
# ...          ...      ...     ...                    ...      ...       ...
# 99995          4       29      72                     43       92        94
# 99996         46       14      36                     46       82        48
# 99997         12       19      83                     35       29        70
# 99998         51       14      22                     63       27        52
# 99999         53       44      85                     69       81        67
#
#        Computer  Defence                                           Interest
# 0            81       28                    Environmental Studies, Geometry
# 1            57       30              Hindi, English, Environmental Studies
# 2            85       31  Marathi, Environmental Studies, Algebra, Computer
# 3            47       87                           Drawing, Sports, Defence
# 4            45       60                                  Marathi, Geometry
# ...         ...      ...                                                ...
# 99995        91       80                                  English, Geometry
# 99996         9       19                                   English, Algebra
# 99997        79       96                                   English, Defence
# 99998        50       47                                   Marathi, History
# 99999        50       44                           History, Sports, Algebra
#
# [100000 rows x 16 columns]

# %%
df_10th=pd.read_csv("Latest10th.csv")
df_10th
# Out:
#          Unique_ID  Marathi  Urdu  Hindi  English  History  Science  \
# 0           stud_1       57    15     96       79       52       85
# 1           stud_2       26    23     99       75       64       44
# 2           stud_3       77    78     45       91       77       24
# 3           stud_4       34    58     31       21       51       83
# 4           stud_5       38    21     20       98       75       21
# ...            ...      ...   ...    ...      ...      ...      ...
# 99995   stud_99996       75    97     60       38       86       78
# 99996   stud_99997       93    13     84       63       79       81
# 99997   stud_99998       91    51     33       61        2       12
# 99998   stud_99999        7    95     87       65       46       10
# 99999  stud_100000       30    46     81       87       43       72
#
#        Geography  Drawing  Sports  Environmental Studies  Algebra  Geometry  \
# 0             29       36      38                      8       63        15
# 1             14       75      38                     11       52        99
# 2             47        1      51                     87       87        31
# 3             23       80      22                     78       92        44
# 4             50       35      72                     64       28        15
# ...          ...      ...     ...                    ...      ...       ...
# 99995         73       68      55                     16       81        16
# 99996         42       44      23                     62       75         4
# 99997         75       81      25                     86       13        80
# 99998         22       52      38                     32       30        93
# 99999         10       44      44                     99       12        28
#
#        Computer  Defence  Sanskrit                                 Interest
# 0            65       77        96                 Hindi, Science, Sanskrit
# 1            98       86        45                Hindi, Geometry, Computer
# 2            42       28         9  English, Environmental Studies, Algebra
# 3            78       85        73                         Algebra, Defence
# 4            36       37         2                         English, History
# ...         ...      ...       ...                                      ...
# 99995         5       43        73                            Urdu, History
# 99996        89       31        36                        Marathi, Computer
# 99997        42        2        53           Marathi, Environmental Studies
# 99998        22       96        40                            Urdu, Defence
# 99999        60       65        42           English, Environmental Studies
#
# [100000 rows x 17 columns]

# %%
#Combined Interest of 5th and 6th (final_Interest)
# Ensure the datasets have a unique identifier column (e.g., "Unique_ID")
if "Unique_ID" not in df_5th.columns or "Unique_ID" not in df_6th.columns:
    raise ValueError("Both datasets must contain a 'Unique_ID' column.")

# Merge the datasets on the Unique_ID column
merged_df = pd.merge(df_5th[["Unique_ID", "Interest"]], df_6th[["Unique_ID", "Interest"]], on="Unique_ID", suffixes=("_5th", "_6th"))

# Function to handle interests based on conditions
def handle_interests(row):
    # Split interests into sets
    interests_5th = set(subject.strip() for subject in row["Interest_5th"].split(","))
    interests_6th = set(subject.strip() for subject in row["Interest_6th"].split(","))
    
    # Find common subjects
    common = interests_5th.intersection(interests_6th)
    
    # If common subjects exist, take those from 5th std and all from 6th std
    if common:
        result = list(common) + list(interests_6th)
    # If no common subjects, take all unique subjects
    else:
        result = list(interests_5th.union(interests_6th))
    
    # Return as a comma-separated string
    return ", ".join(sorted(set(result)))

# Apply the function to determine final interests
merged_df["Final_Interests"] = merged_df.apply(handle_interests, axis=1)
merged_df
# Out:
#        Unique_ID                            Interest_5th  \
# 0         stud_1                   Drawing, Sports, Math
# 1         stud_2                  Hindi, Drawing, Sports
# 2         stud_3                          Hindi, History
# 3         stud_4                          Hindi, English
# 4         stud_5                     Geography, Computer
# ...          ...                                     ...
# 9995   stud_9996                           History, Math
# 9996   stud_9997              History, Geography, Sports
# 9997   stud_9998                Science, Geography, Math
# 9998   stud_9999                        English, Drawing
# 9999  stud_10000  Marathi, Sports, Environmental Studies
#
#                                  Interest_6th  \
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
#                                        Final_Interests
# 0                             Geography, History, Math
# 1              Drawing, Environmental Studies, History
# 2       English, Environmental Studies, Hindi, History
# 3     English, Environmental Studies, Geography, Hindi
# 4                                     Computer, Sports
# ...                                                ...
# 9995                     Computer, History, Math, Urdu
# 9996        English, Geography, Hindi, History, Sports
# 9997            Geography, Math, Science, Sports, Urdu
# 9998                    Drawing, English, Math, Sports
# 9999                     Environmental Studies, Sports
#
# [10000 rows x 4 columns]

# %%
# Ensure 'Interest' columns are strings for processing
merged_df["Final_Interests"] = merged_df["Final_Interests"].astype(str)
df_7th["Interest"] = df_7th["Interest"].astype(str)

# Merge the existing merged_df with the 7th standard dataset
merged_df7th = pd.merge(
    merged_df,
    df_7th[["Unique_ID", "Interest"]],
    on="Unique_ID",
    how="inner",
    suffixes=("", "_7th")
)

# Verify the column names after merging
#print(final_merged_df.columns)

# Function to handle interests across 5th, 6th, and 7th standards
def handle_interests_7th(row):
    # Split interests into sets
    interests_5th_6th = set(subject.strip() for subject in row["Final_Interests"].split(","))
    interests_7th = set(subject.strip() for subject in row["Interest"].split(","))  # Adjusted column name
   
    # Find common subjects
    common = interests_5th_6th.intersection(interests_7th)
   
    # If common subjects exist, take those from 5th-6th Final_Interests and all from 7th std
    if common:
        result = list(common) + list(interests_7th)
    # If no common subjects, take all unique subjects
    else:
        result = list(interests_5th_6th.union(interests_7th))
   
    # Return as a comma-separated string
    return ", ".join(sorted(set(result)))

# Apply the function to determine final interests across all three standards
merged_df7th["Final_Interests_7th"] = merged_df7th.apply(handle_interests_7th, axis=1)

# Save the results to a new CSV file
# output_path = "Final_Interests_5th_6th_7th.csv"
# final_merged_df.to_csv(output_path, index=False)
# print(f"Results saved to {output_path}")

# Display the resulting DataFrame
merged_df7th
# Out:
#        Unique_ID                            Interest_5th  \
# 0         stud_1                   Drawing, Sports, Math
# 1         stud_2                  Hindi, Drawing, Sports
# 2         stud_3                          Hindi, History
# 3         stud_4                          Hindi, English
# 4         stud_5                     Geography, Computer
# ...          ...                                     ...
# 9995   stud_9996                           History, Math
# 9996   stud_9997              History, Geography, Sports
# 9997   stud_9998                Science, Geography, Math
# 9998   stud_9999                        English, Drawing
# 9999  stud_10000  Marathi, Sports, Environmental Studies
#
#                                  Interest_6th  \
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
#                                        Final_Interests  \
# 0                             Geography, History, Math
# 1              Drawing, Environmental Studies, History
# 2       English, Environmental Studies, Hindi, History
# 3     English, Environmental Studies, Geography, Hindi
# 4                                     Computer, Sports
# ...                                                ...
# 9995                     Computer, History, Math, Urdu
# 9996        English, Geography, Hindi, History, Sports
# 9997            Geography, Math, Science, Sports, Urdu
# 9998                    Drawing, English, Math, Sports
# 9999                     Environmental Studies, Sports
#
#                                                Interest  \
# 0     Marathi, Hindi, History, Geography, Math, Comp...
# 1     Urdu, Science, Drawing, Sports, Environmental ...
# 2     English, Science, Environmental Studies, Math,...
# 3     Urdu, Science, Geography, Drawing, Environment...
# 4                                      Sports, Computer
# ...                                                 ...
# 9995                                     Urdu, Computer
# 9996                                     Hindi, English
# 9997                                       Urdu, Sports
# 9998                                       Sports, Math
# 9999                      Sports, Environmental Studies
#
#                                     Final_Interests_7th
# 0     Computer, Geography, Hindi, History, Marathi, ...
# 1     Drawing, Environmental Studies, Science, Sport...
# 2     Computer, English, Environmental Studies, Math...
# 3     Drawing, Environmental Studies, Geography, Sci...
# 4                                      Computer, Sports
# ...                                                 ...
# 9995                                     Computer, Urdu
# 9996                                     English, Hindi
# 9997                                       Sports, Urdu
# 9998                                       Math, Sports
# 9999                      Environmental Studies, Sports
#
# [10000 rows x 6 columns]

# %%
# Final_Interests_7th + Interest_8th = Final_Interests_8th
# Ensure 'Interest' columns are strings for processing
merged_df7th["Final_Interests_7th"] = merged_df7th["Final_Interests_7th"].astype(str)
df_8th["Interest"] = df_8th["Interest"].astype(str)

# Merge the existing final_merged_df with the 8th standard dataset
final_merged_with_8th = pd.merge(
    merged_df7th, 
    df_8th[["Unique_ID", "Interest"]], 
    on="Unique_ID", 
    how="inner", 
    suffixes=("", "_8th")  # Added suffix to avoid name conflicts
)

# Check column names after the merge to ensure correct references
print(final_merged_with_8th.columns)

# Function to handle interests across all standards (5th, 6th, 7th, and 8th)
def handle_interests_8th(row):
    # Adjust column names if suffixes are added during the merge
    interests_7th = set(subject.strip() for subject in row["Final_Interests_7th"].split(","))
    interests_8th = set(subject.strip() for subject in row["Interest_8th"].split(","))
    
    # Find common subjects
    common = interests_7th.intersection(interests_8th)
    
    # If common subjects exist, take those from 7th and all from 8th
    if common:
        result = list(common) + list(interests_8th)
    # If no common subjects, take all unique subjects
    else:
        result = list(interests_7th.union(interests_8th))
    
    # Return as a comma-separated string
    return ", ".join(sorted(set(result)))

# Apply the function to determine final interests across all standards
final_merged_with_8th["Final_Interests_8th"] = final_merged_with_8th.apply(handle_interests_8th, axis=1)

# Save the results to a new CSV file
output_path = "Final_Interests_5th_6th_7th_8th.csv"
final_merged_with_8th.to_csv(output_path, index=False)
print(f"Results saved to {output_path}")


# Display the resulting DataFrame
final_merged_with_8th
# Out:
# Index(['Unique_ID', 'Interest_5th', 'Interest_6th', 'Final_Interests',
#        'Interest', 'Final_Interests_7th', 'Interest_8th'],
#       dtype='object')
# Results saved to Final_Interests_5th_6th_7th_8th.csv
# Index(['Unique_ID', 'Interest_5th', 'Interest_6th', 'Final_Interests',
#        'Interest', 'Final_Interests_7th', 'Interest_8th',
#        'Final_Interests_8th'],
#       dtype='object')
#        Unique_ID                            Interest_5th  \
# 0         stud_1                   Drawing, Sports, Math
# 1         stud_2                  Hindi, Drawing, Sports
# 2         stud_3                          Hindi, History
# 3         stud_4                          Hindi, English
# 4         stud_5                     Geography, Computer
# ...          ...                                     ...
# 9995   stud_9996                           History, Math
# 9996   stud_9997              History, Geography, Sports
# 9997   stud_9998                Science, Geography, Math
# 9998   stud_9999                        English, Drawing
# 9999  stud_10000  Marathi, Sports, Environmental Studies
#
#                                  Interest_6th  \
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
#                                        Final_Interests  \
# 0                             Geography, History, Math
# 1              Drawing, Environmental Studies, History
# 2       English, Environmental Studies, Hindi, History
# 3     English, Environmental Studies, Geography, Hindi
# 4                                     Computer, Sports
# ...                                                ...
# 9995                     Computer, History, Math, Urdu
# 9996        English, Geography, Hindi, History, Sports
# 9997            Geography, Math, Science, Sports, Urdu
# 9998                    Drawing, English, Math, Sports
# 9999                     Environmental Studies, Sports
#
#                                                Interest  \
# 0     Marathi, Hindi, History, Geography, Math, Comp...
# 1     Urdu, Science, Drawing, Sports, Environmental ...
# 2     English, Science, Environmental Studies, Math,...
# 3     Urdu, Science, Geography, Drawing, Environment...
# 4                                      Sports, Computer
# ...                                                 ...
# 9995                                     Urdu, Computer
# 9996                                     Hindi, English
# 9997                                       Urdu, Sports
# 9998                                       Sports, Math
# 9999                      Sports, Environmental Studies
#
#                                     Final_Interests_7th  \
# 0     Computer, Geography, Hindi, History, Marathi, ...
# 1     Drawing, Environmental Studies, Science, Sport...
# 2     Computer, English, Environmental Studies, Math...
# 3     Drawing, Environmental Studies, Geography, Sci...
# 4                                      Computer, Sports
# ...                                                 ...
# 9995                                     Computer, Urdu
# 9996                                     English, Hindi
# 9997                                       Sports, Urdu
# 9998                                       Math, Sports
# 9999                      Environmental Studies, Sports
#
#                                  Interest_8th  \
# 0                   Marathi, English, History
# 1                         Urdu, History, Math
# 2                      Urdu, English, Science
# 3     English, Drawing, Environmental Studies
# 4                      Marathi, Urdu, Drawing
# ...                                       ...
# 9995                        History, Computer
# 9996                             Urdu, Sports
# 9997           Science, Environmental Studies
# 9998                   Urdu, English, Drawing
# 9999                           Math, Computer
#
#                                 Final_Interests_8th
# 0                         English, History, Marathi
# 1                               History, Math, Urdu
# 2                            English, Science, Urdu
# 3           Drawing, English, Environmental Studies
# 4          Computer, Drawing, Marathi, Sports, Urdu
# ...                                             ...
# 9995                              Computer, History
# 9996                   English, Hindi, Sports, Urdu
# 9997   Environmental Studies, Science, Sports, Urdu
# 9998           Drawing, English, Math, Sports, Urdu
# 9999  Computer, Environmental Studies, Math, Sports
#
# [10000 rows x 8 columns]

# %%
# Final_Interests_7th + Interest_8th = Final_Interests_8th
# Ensure 'Interest' columns are strings for processing
final_merged_with_8th["Final_Interests_8th"] = final_merged_with_8th["Final_Interests_8th"].astype(str)
df_9th["Interest"] = df_9th["Interest"].astype(str)

# Merge the existing final_merged_df with the 8th standard dataset
final_merged_with_9th = pd.merge(
   final_merged_with_8th, 
    df_9th[["Unique_ID", "Interest"]], 
    on="Unique_ID", 
    how="inner", 
    suffixes=("", "_9th")  # Added suffix to avoid name conflicts
)

# Check column names after the merge to ensure correct references
# print(final_merged_with_9th.columns)

# Function to handle interests across all standards (5th, 6th, 7th, and 8th)
def handle_interests_9th(row):
    # Adjust column names if suffixes are added during the merge
    interests_8th = set(subject.strip() for subject in row["Final_Interests_8th"].split(","))
    interests_9th = set(subject.strip() for subject in row["Interest_9th"].split(","))
    
    # Find common subjects
    common = interests_8th.intersection(interests_9th)
    
    # If common subjects exist, take those from 7th and all from 8th
    if common:
        result = list(common) + list(interests_9th)
    # If no common subjects, take all unique subjects
    else:
        result = list(interests_8th.union(interests_9th))
    
    # Return as a comma-separated string
    return ", ".join(sorted(set(result)))

# Apply the function to determine final interests across all standards
final_merged_with_9th["Final_Interests_9th"] = final_merged_with_9th.apply(handle_interests_9th, axis=1)

# Save the results to a new CSV file
output_path = "Final_Interests_5th_6th_7th_8th_9th.csv"
final_merged_with_9th.to_csv(output_path, index=False)
print(f"Results saved to {output_path}")

print(final_merged_with_9th.columns)
# Display the resulting DataFrame
final_merged_with_9th
# Out:
# Results saved to Final_Interests_5th_6th_7th_8th_9th.csv
# Index(['Unique_ID', 'Interest_5th', 'Interest_6th', 'Final_Interests',
#        'Interest', 'Final_Interests_7th', 'Interest_8th',
#        'Final_Interests_8th', 'Interest_9th', 'Final_Interests_9th'],
#       dtype='object')
#        Unique_ID                            Interest_5th  \
# 0         stud_1                   Drawing, Sports, Math
# 1         stud_2                  Hindi, Drawing, Sports
# 2         stud_3                          Hindi, History
# 3         stud_4                          Hindi, English
# 4         stud_5                     Geography, Computer
# ...          ...                                     ...
# 9995   stud_9996                           History, Math
# 9996   stud_9997              History, Geography, Sports
# 9997   stud_9998                Science, Geography, Math
# 9998   stud_9999                        English, Drawing
# 9999  stud_10000  Marathi, Sports, Environmental Studies
#
#                                  Interest_6th  \
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
#                                        Final_Interests  \
# 0                             Geography, History, Math
# 1              Drawing, Environmental Studies, History
# 2       English, Environmental Studies, Hindi, History
# 3     English, Environmental Studies, Geography, Hindi
# 4                                     Computer, Sports
# ...                                                ...
# 9995                     Computer, History, Math, Urdu
# 9996        English, Geography, Hindi, History, Sports
# 9997            Geography, Math, Science, Sports, Urdu
# 9998                    Drawing, English, Math, Sports
# 9999                     Environmental Studies, Sports
#
#                                                Interest  \
# 0     Marathi, Hindi, History, Geography, Math, Comp...
# 1     Urdu, Science, Drawing, Sports, Environmental ...
# 2     English, Science, Environmental Studies, Math,...
# 3     Urdu, Science, Geography, Drawing, Environment...
# 4                                      Sports, Computer
# ...                                                 ...
# 9995                                     Urdu, Computer
# 9996                                     Hindi, English
# 9997                                       Urdu, Sports
# 9998                                       Sports, Math
# 9999                      Sports, Environmental Studies
#
#                                     Final_Interests_7th  \
# 0     Computer, Geography, Hindi, History, Marathi, ...
# 1     Drawing, Environmental Studies, Science, Sport...
# 2     Computer, English, Environmental Studies, Math...
# 3     Drawing, Environmental Studies, Geography, Sci...
# 4                                      Computer, Sports
# ...                                                 ...
# 9995                                     Computer, Urdu
# 9996                                     English, Hindi
# 9997                                       Sports, Urdu
# 9998                                       Math, Sports
# 9999                      Environmental Studies, Sports
#
#                                  Interest_8th  \
# 0                   Marathi, English, History
# 1                         Urdu, History, Math
# 2                      Urdu, English, Science
# 3     English, Drawing, Environmental Studies
# 4                      Marathi, Urdu, Drawing
# ...                                       ...
# 9995                        History, Computer
# 9996                             Urdu, Sports
# 9997           Science, Environmental Studies
# 9998                   Urdu, English, Drawing
# 9999                           Math, Computer
#
#                                 Final_Interests_8th  \
# 0                         English, History, Marathi
# 1                               History, Math, Urdu
# 2                            English, Science, Urdu
# 3           Drawing, English, Environmental Studies
# 4          Computer, Drawing, Marathi, Sports, Urdu
# ...                                             ...
# 9995                              Computer, History
# 9996                   English, Hindi, Sports, Urdu
# 9997   Environmental Studies, Science, Sports, Urdu
# 9998           Drawing, English, Math, Sports, Urdu
# 9999  Computer, Environmental Studies, Math, Sports
#
#                                            Interest_9th  \
# 0                       Environmental Studies, Geometry
# 1                 Hindi, English, Environmental Studies
# 2     Marathi, Environmental Studies, Algebra, Computer
# 3                              Drawing, Sports, Defence
# 4                                     Marathi, Geometry
# ...                                                 ...
# 9995                     Environmental Studies, Algebra
# 9996                                   History, Algebra
# 9997            Drawing, Environmental Studies, Defence
# 9998                                   Marathi, Defence
# 9999                                 English, Geography
#
#                                     Final_Interests_9th
# 0     English, Environmental Studies, Geometry, Hist...
# 1     English, Environmental Studies, Hindi, History...
# 2     Algebra, Computer, English, Environmental Stud...
# 3                              Defence, Drawing, Sports
# 4                                     Geometry, Marathi
# ...                                                 ...
# 9995  Algebra, Computer, Environmental Studies, History
# 9996     Algebra, English, Hindi, History, Sports, Urdu
# 9997            Defence, Drawing, Environmental Studies
# 9998  Defence, Drawing, English, Marathi, Math, Spor...
# 9999  Computer, English, Environmental Studies, Geog...
#
# [10000 rows x 10 columns]

# %%
# Final_Interests_7th + Interest_8th = Final_Interests_8th
# Ensure 'Interest' columns are strings for processing
final_merged_with_9th["Final_Interests_9th"] = final_merged_with_9th["Final_Interests_9th"].astype(str)
df_10th["Interest"] = df_10th["Interest"].astype(str)

# Merge the existing final_merged_df with the 8th standard dataset
final_merged_with_10th = pd.merge(
   final_merged_with_9th, 
    df_10th[["Unique_ID", "Interest"]], 
    on="Unique_ID", 
    how="inner", 
    suffixes=("", "_10th")  # Added suffix to avoid name conflicts
)

# Check column names after the merge to ensure correct references

# print(final_merged_with_9th.columns)

# Function to handle interests across all standards (5th, 6th, 7th, and 8th)
def handle_interests_10th(row):
    # Adjust column names if suffixes are added during the merge
    interests_9th = set(subject.strip() for subject in row["Final_Interests_9th"].split(","))
    interests_10th = set(subject.strip() for subject in row["Interest_10th"].split(","))
    
    # Find common subjects
    common = interests_9th.intersection(interests_10th)
    
    # If common subjects exist, take those from 7th and all from 8th
    if common:
        result = list(common) + list(interests_10th)
    # If no common subjects, take all unique subjects
    else:
        result = list(interests_9th.union(interests_10th))
    
    # Return as a comma-separated string
    return ", ".join(sorted(set(result)))

# Apply the function to determine final interests across all standards
final_merged_with_10th["Final_Interests_10th"] = final_merged_with_10th.apply(handle_interests_10th, axis=1)

# Save the results to a new CSV file
output_path = "Final_Interests_5th_6th_7th_8th_9th_10th.csv"
final_merged_with_10th.to_csv(output_path, index=False)
print(f"Results saved to {output_path}")

print(final_merged_with_10th.columns)

# Display the resulting DataFrame
final_merged_with_10th
# Out:
# Results saved to Final_Interests_5th_6th_7th_8th_9th_10th.csv
# Index(['Unique_ID', 'Interest_5th', 'Interest_6th', 'Final_Interests',
#        'Interest', 'Final_Interests_7th', 'Interest_8th',
#        'Final_Interests_8th', 'Interest_9th', 'Final_Interests_9th',
#        'Interest_10th', 'Final_Interests_10th'],
#       dtype='object')
#        Unique_ID                            Interest_5th  \
# 0         stud_1                   Drawing, Sports, Math
# 1         stud_2                  Hindi, Drawing, Sports
# 2         stud_3                          Hindi, History
# 3         stud_4                          Hindi, English
# 4         stud_5                     Geography, Computer
# ...          ...                                     ...
# 9995   stud_9996                           History, Math
# 9996   stud_9997              History, Geography, Sports
# 9997   stud_9998                Science, Geography, Math
# 9998   stud_9999                        English, Drawing
# 9999  stud_10000  Marathi, Sports, Environmental Studies
#
#                                  Interest_6th  \
# 0                    History, Geography, Math
# 1     History, Drawing, Environmental Studies
# 2              English, Environmental Studies
# 3            Geography, Environmental Studies
# 4                            Sports, Computer
# ...                                       ...
# 9995                           Urdu, Computer
# 9996                           Hindi, English
# 9997                             Urdu, Sports
# 9998                             Sports, Math
# 9999            Sports, Environmental Studies
#
#                                        Final_Interests  \
# 0                             Geography, History, Math
# 1              Drawing, Environmental Studies, History
# 2       English, Environmental Studies, Hindi, History
# 3     English, Environmental Studies, Geography, Hindi
# 4                                     Computer, Sports
# ...                                                ...
# 9995                     Computer, History, Math, Urdu
# 9996        English, Geography, Hindi, History, Sports
# 9997            Geography, Math, Science, Sports, Urdu
# 9998                    Drawing, English, Math, Sports
# 9999                     Environmental Studies, Sports
#
#                                                Interest  \
# 0     Marathi, Hindi, History, Geography, Math, Comp...
# 1     Urdu, Science, Drawing, Sports, Environmental ...
# 2     English, Science, Environmental Studies, Math,...
# 3     Urdu, Science, Geography, Drawing, Environment...
# 4                                      Sports, Computer
# ...                                                 ...
# 9995                                     Urdu, Computer
# 9996                                     Hindi, English
# 9997                                       Urdu, Sports
# 9998                                       Sports, Math
# 9999                      Sports, Environmental Studies
#
#                                     Final_Interests_7th  \
# 0     Computer, Geography, Hindi, History, Marathi, ...
# 1     Drawing, Environmental Studies, Science, Sport...
# 2     Computer, English, Environmental Studies, Math...
# 3     Drawing, Environmental Studies, Geography, Sci...
# 4                                      Computer, Sports
# ...                                                 ...
# 9995                                     Computer, Urdu
# 9996                                     English, Hindi
# 9997                                       Sports, Urdu
# 9998                                       Math, Sports
# 9999                      Environmental Studies, Sports
#
#                                  Interest_8th  \
# 0                   Marathi, English, History
# 1                         Urdu, History, Math
# 2                      Urdu, English, Science
# 3     English, Drawing, Environmental Studies
# 4                      Marathi, Urdu, Drawing
# ...                                       ...
# 9995                        History, Computer
# 9996                             Urdu, Sports
# 9997           Science, Environmental Studies
# 9998                   Urdu, English, Drawing
# 9999                           Math, Computer
#
#                                 Final_Interests_8th  \
# 0                         English, History, Marathi
# 1                               History, Math, Urdu
# 2                            English, Science, Urdu
# 3           Drawing, English, Environmental Studies
# 4          Computer, Drawing, Marathi, Sports, Urdu
# ...                                             ...
# 9995                              Computer, History
# 9996                   English, Hindi, Sports, Urdu
# 9997   Environmental Studies, Science, Sports, Urdu
# 9998           Drawing, English, Math, Sports, Urdu
# 9999  Computer, Environmental Studies, Math, Sports
#
#                                            Interest_9th  \
# 0                       Environmental Studies, Geometry
# 1                 Hindi, English, Environmental Studies
# 2     Marathi, Environmental Studies, Algebra, Computer
# 3                              Drawing, Sports, Defence
# 4                                     Marathi, Geometry
# ...                                                 ...
# 9995                     Environmental Studies, Algebra
# 9996                                   History, Algebra
# 9997            Drawing, Environmental Studies, Defence
# 9998                                   Marathi, Defence
# 9999                                 English, Geography
#
#                                     Final_Interests_9th  \
# 0     English, Environmental Studies, Geometry, Hist...
# 1     English, Environmental Studies, Hindi, History...
# 2     Algebra, Computer, English, Environmental Stud...
# 3                              Defence, Drawing, Sports
# 4                                     Geometry, Marathi
# ...                                                 ...
# 9995  Algebra, Computer, Environmental Studies, History
# 9996     Algebra, English, Hindi, History, Sports, Urdu
# 9997            Defence, Drawing, Environmental Studies
# 9998  Defence, Drawing, English, Marathi, Math, Spor...
# 9999  Computer, English, Environmental Studies, Geog...
#
#                                 Interest_10th  \
# 0                    Hindi, Science, Sanskrit
# 1                   Hindi, Geometry, Computer
# 2     English, Environmental Studies, Algebra
# 3                            Algebra, Defence
# 4                            English, History
# ...                                       ...
# 9995                             Urdu, Sports
# 9996                          Hindi, Computer
# 9997                         English, Drawing
# 9998                        Geometry, Defence
# 9999                           Urdu, Geometry
#
#                                    Final_Interests_10th
# 0     English, Environmental Studies, Geometry, Hind...
# 1                             Computer, Geometry, Hindi
# 2               Algebra, English, Environmental Studies
# 3                                      Algebra, Defence
# 4                   English, Geometry, History, Marathi
# ...                                                 ...
# 9995  Algebra, Computer, Environmental Studies, Hist...
# 9996                                    Computer, Hindi
# 9997                                   Drawing, English
# 9998                                  Defence, Geometry
# 9999  Computer, English, Environmental Studies, Geog...
#
# [10000 rows x 12 columns]
